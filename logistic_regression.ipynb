# %% [markdown]
# <a href="https://colab.research.google.com/github/Thamindu17/google-colab/blob/main/logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('sample.csv')

# %%
data.head()
# Out:
#    age  job
# 0   16    0
# 1   24    0
# 2   31    1
# 3   29    0
# 4   40    1

# %%
plt.scatter(data.age,data.job)

# %%
x=data[["age"]]
y=data["job"]

# %%
x
# Out:
#     age
# 0    16
# 1    24
# 2    31
# 3    29
# 4    40
# 5    33
# 6    18
# 7    36
# 8    15
# 9    37
# 10   19
# 11   21
# 12   29
# 13   31
# 14   23
# 15   20
# 16   34
# 17   22
# 18   32
# 19   15
# 20   14
# 21   13
# 22   51
# 23   43
# 24   23
# 25   31

# %%
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     0
# 6     0
# 7     1
# 8     0
# 9     1
# 10    0
# 11    0
# 12    1
# 13    1
# 14    1
# 15    0
# 16    1
# 17    0
# 18    1
# 19    0
# 20    0
# 21    0
# 22    1
# 23    1
# 24    0
# 25    1
# Name: job, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#     age
# 18   32
# 8    15
# 25   31
# 1    24
# 10   19
# 3    29
# 17   22
# 23   43
# 15   20
# 0    16
# 6    18
# 12   29
# 19   15
# 20   14
# 13   31
# 2    31
# 7    36
# 22   51
# 11   21
# 9    37

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 0, 0, 1, 1, 1])

# %%
x_test
# Out:
#     age
# 24   23
# 14   23
# 21   13
# 4    40
# 5    33
# 16   34

# %%
y_test
# Out:
# 24    0
# 14    1
# 21    0
# 4     1
# 5     0
# 16    1
# Name: job, dtype: int64

# %%
model.score(x_test,y_test)
# Out:
# 0.6666666666666666

# %%
age=[[31]]
model.predict(age)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])
